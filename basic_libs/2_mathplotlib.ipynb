# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Data/housing.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
rooms=df[['total_bedrooms','total_rooms']]
rooms
# Out:
#        total_bedrooms  total_rooms
# 0               129.0        880.0
# 1              1106.0       7099.0
# 2               190.0       1467.0
# 3               235.0       1274.0
# 4               280.0       1627.0
# ...               ...          ...
# 20635           374.0       1665.0
# 20636           150.0        697.0
# 20637           485.0       2254.0
# 20638           409.0       1860.0
# 20639           616.0       2785.0
#
# [20640 rows x 2 columns]

# %%
plt.figure(dpi=75)
plt.hist(df['total_rooms'])

plt.title('Histogram of Rooms')
plt.ylabel('Count')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
plt.figure(dpi=75)
plt.plot(df['total_bedrooms'][:10000])

# %%
plt.figure(dpi=75)
plt.scatter(df['total_bedrooms'][:100],df['total_rooms'][:100])

# %% [raw]
# plt.figure(dpi=75)
# plt.scatter(df['total_bedrooms'],df['total_rooms'])

# %%
rooms.corr()
# Out:
#                 total_bedrooms  total_rooms
# total_bedrooms         1.00000      0.93038
# total_rooms            0.93038      1.00000

# %%
plt.figure(dpi=75)
plt.scatter(df['total_bedrooms'][:100],df['total_rooms'][:100])
plt.scatter(df['total_bedrooms'][100:200],df['total_rooms'][100:200])
plt.scatter(df['total_bedrooms'][200:230],df['total_rooms'][200:230])
plt.legend(['First 100','Second 100','Third 30'])

# %%
plt.boxplot(df['total_rooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18e1e669360>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18e1e669900>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18e1e6691b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18e1e669ea0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18e1e66a170>],
#  'means': []}

# %%
bins_series=pd.cut(df['total_rooms'],bins=4).value_counts()
bins_series
# Out:
# (-37.318, 9831.5]     20334
# (9831.5, 19661.0]       273
# (19661.0, 29490.5]       26
# (29490.5, 39320.0]        7
# Name: total_rooms, dtype: int64

# %%
values=bins_series.to_list()
values
# Out:
# [20334, 273, 26, 7]

# %%
labels=[str(x) for x in bins_series.index.to_list()]
labels
# Out:
# ['(-37.318, 9831.5]',
#  '(9831.5, 19661.0]',
#  '(19661.0, 29490.5]',
#  '(29490.5, 39320.0]']

# %%
plt.figure(dpi=80)
plt.pie(values,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x18e238ec250>,
# ...
#  [Text(-1.0988070906152552, 0.05121501355694972, '(-37.318, 9831.5]'),
#   Text(1.0985359826462344, -0.0567335423843119, '(9831.5, 19661.0]'),
#   Text(1.0999796125436867, -0.00669716270079652, '(19661.0, 29490.5]'),
#   Text(1.0999993756230866, -0.0011720191209869339, '(29490.5, 39320.0]')])

# %%
plt.bar(labels,height=values)
# Out:
# <BarContainer object of 4 artists>
