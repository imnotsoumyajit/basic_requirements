# %% [markdown]
# #### Basically a higher level of matplotlib

# %%
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('Data/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
g=sns.relplot(kind='scatter',data=df,x='longitude',y='latitude',hue='ocean_proximity')
g.set(title='Geo Location of areas in California')

# %%
df['above_median_house_value']=(df.median_house_value>df.median_house_value.median()).astype(int)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
g=sns.relplot(kind='scatter',data=df,x='longitude',
              y='latitude', style='above_median_house_value',
              hue='above_median_house_value')

# %%
g=sns.relplot(kind='scatter',data=df,x='longitude',y='latitude',style='above_median_house_value')

# %%
g=sns.relplot(kind='scatter',data=df,x='longitude',
              y='latitude', size='above_median_house_value',
              hue='above_median_house_value')

# %%
from tensorflow.keras.utils import get_file
from copy import deepcopy
import os

# %%
zip_path = get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)

csv_path,_=os.path.splitext(zip_path)
weather_df=pd.read_csv(csv_path)
weather_df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
# We want 6 points 24 times a day for 365 days 
weather_df=weather_df[::6*24][:365]
weather_df.reset_index(drop=True,inplace=True)

weather_df_full=deepcopy(weather_df)

weather_df=weather_df[['Date Time','p (mbar)','T (degC)']]
weather_df
# Out:
#                Date Time  p (mbar)  T (degC)
# 0    01.01.2009 00:10:00    996.52     -8.02
# 1    02.01.2009 00:10:00    999.55     -4.60
# 2    03.01.2009 00:10:00   1002.39     -4.89
# 3    04.01.2009 00:10:00    992.79     -1.83
# 4    05.01.2009 00:10:00    985.06     -1.50
# ..                   ...       ...       ...
# 360  27.12.2009 00:30:00    981.38     -0.70
# 361  28.12.2009 00:30:00    975.40      1.66
# 362  29.12.2009 00:30:00    981.81     -2.18
# 363  30.12.2009 00:30:00    969.94     -0.70
# 364  31.12.2009 00:30:00    967.84     -0.68
#
# [365 rows x 3 columns]

# %%
weather_df['Date Time']
# Out:
# 0      01.01.2009 00:10:00
# 1      02.01.2009 00:10:00
# 2      03.01.2009 00:10:00
# 3      04.01.2009 00:10:00
# 4      05.01.2009 00:10:00
#               ...
# 360    27.12.2009 00:30:00
# 361    28.12.2009 00:30:00
# 362    29.12.2009 00:30:00
# 363    30.12.2009 00:30:00
# 364    31.12.2009 00:30:00
# Name: Date Time, Length: 365, dtype: object

# %%
weather_df=deepcopy(weather_df)
weather_df['Date Time']=pd.to_datetime(weather_df['Date Time'],format='%d.%m.%Y %H:%M:%S')

weather_df['Date Time']
# Out:
# 0     2009-01-01 00:10:00
# 1     2009-01-02 00:10:00
# 2     2009-01-03 00:10:00
# 3     2009-01-04 00:10:00
# 4     2009-01-05 00:10:00
#               ...
# 360   2009-12-27 00:30:00
# 361   2009-12-28 00:30:00
# 362   2009-12-29 00:30:00
# 363   2009-12-30 00:30:00
# 364   2009-12-31 00:30:00
# Name: Date Time, Length: 365, dtype: datetime64[ns]

# %%
weather_df.head()
# Out:
#             Date Time  p (mbar)  T (degC)
# 0 2009-01-01 00:10:00    996.52     -8.02
# 1 2009-01-02 00:10:00    999.55     -4.60
# 2 2009-01-03 00:10:00   1002.39     -4.89
# 3 2009-01-04 00:10:00    992.79     -1.83
# 4 2009-01-05 00:10:00    985.06     -1.50

# %%
sns.lineplot(x='Date Time',y='T (degC)',data=weather_df)
# Out:
# <AxesSubplot:xlabel='Date Time', ylabel='T (degC)'>

# %%
g=sns.lineplot(x='Date Time',y='T (degC)',data=weather_df)
g.figure.autofmt_xdate()

# %%
weather_df['above_avg_pressure']=(weather_df['p (mbar)']>weather_df['p (mbar)'].mean()).astype(int)
weather_df
# Out:
#               Date Time  p (mbar)  T (degC)  above_avg_pressure
# 0   2009-01-01 00:10:00    996.52     -8.02                   1
# 1   2009-01-02 00:10:00    999.55     -4.60                   1
# 2   2009-01-03 00:10:00   1002.39     -4.89                   1
# 3   2009-01-04 00:10:00    992.79     -1.83                   1
# 4   2009-01-05 00:10:00    985.06     -1.50                   0
# ..                  ...       ...       ...                 ...
# 360 2009-12-27 00:30:00    981.38     -0.70                   0
# 361 2009-12-28 00:30:00    975.40      1.66                   0
# 362 2009-12-29 00:30:00    981.81     -2.18                   0
# 363 2009-12-30 00:30:00    969.94     -0.70                   0
# 364 2009-12-31 00:30:00    967.84     -0.68                   0
#
# [365 rows x 4 columns]

# %%
weather_df_shuffled = weather_df.sample(frac=1)
weather_df_shuffled.reset_index(drop=True, inplace=True)

weather_df_shuffled
# Out:
#               Date Time  p (mbar)  T (degC)  above_avg_pressure
# 0   2009-10-14 00:30:00    999.16      1.53                   1
# 1   2009-06-26 00:10:00    986.37     14.36                   0
# 2   2009-03-31 00:10:00    997.25      0.19                   1
# 3   2009-12-27 00:30:00    981.38     -0.70                   0
# 4   2009-02-16 00:10:00    993.76     -3.03                   1
# ..                  ...       ...       ...                 ...
# 360 2009-11-20 00:30:00    995.71      6.00                   1
# 361 2009-10-17 00:30:00    988.52      3.08                   1
# 362 2009-05-24 00:10:00    992.18     12.40                   1
# 363 2009-08-26 00:10:00    986.21     18.43                   0
# 364 2009-10-29 00:30:00    991.93      6.69                   1
#
# [365 rows x 4 columns]

# %%
g=sns.lineplot(x='Date Time',y='T (degC)',hue='above_avg_pressure',style='above_avg_pressure',data=weather_df_shuffled)
g.figure.autofmt_xdate()

# %% [markdown]
# seperate em as two different columns

# %%
g=sns.relplot(x='Date Time',y='T (degC)',hue='above_avg_pressure',markers=True,style='above_avg_pressure',col='above_avg_pressure',kind='line',data=weather_df_shuffled)
g.figure.autofmt_xdate()

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# categorical plot
